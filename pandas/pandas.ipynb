# %%
# !pip3 install pandas

# %%
import pandas as pd

# %%
data = pd.read_csv("./pandas/Dataset/big_mart_sales.csv")

# %%
data.head(3)
data1 = data

# %%
data1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# 0                     Dairy  249.8092            OUT049      Medium
# ...

# %%
data.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
# check the null value in data 
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# summery of data 
data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
import random

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8523, step=1)

# %%
# chnaging the index of the datar
list_random = [random.randint(1,8523) for i in range(1,8524)]

# %%
data.index = list_random

# %%
data.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1793           FDA15         9.30          Low Fat         0.016047
# 1173           DRC01         5.92          Regular         0.019278
# 4971           FDN15        17.50          Low Fat         0.016760
# 4856           FDX07        19.20          Regular         0.000000
# 5278           NCD19         8.93          Low Fat         0.000000
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 1793                  Dairy  249.8092            OUT049
# 1173            Soft Drinks   48.2692            OUT018
# 4971                   Meat  141.6180            OUT049
# 4856  Fruits and Vegetables  182.0950            OUT010
# 5278              Household   53.8614            OUT013
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 1793                       1999      Medium               Tier 1
# 1173                       2009      Medium               Tier 3
# ...

# %%
data.set_index("Outlet_Establishment_Year" , drop = True ,inplace= True)

# %%
data.head()
# Out:
#                           Item_Identifier  Item_Weight Item_Fat_Content  \
# Outlet_Establishment_Year
# 1999                                FDA15         9.30          Low Fat
# 2009                                DRC01         5.92          Regular
# 1999                                FDN15        17.50          Low Fat
# 1998                                FDX07        19.20          Regular
# 1987                                NCD19         8.93          Low Fat
#
#                            Item_Visibility              Item_Type  Item_MRP  \
# Outlet_Establishment_Year
# 1999                              0.016047                  Dairy  249.8092
# 2009                              0.019278            Soft Drinks   48.2692
# 1999                              0.016760                   Meat  141.6180
# 1998                              0.000000  Fruits and Vegetables  182.0950
# 1987                              0.000000              Household   53.8614
#
# ...

# %%
data.set_index("Item_Identifier", drop=True , inplace = True)

# %%
data.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047
# DRC01                   5.92          Regular         0.019278
# FDN15                  17.50          Low Fat         0.016760
# FDX07                  19.20          Regular         0.000000
# NCD19                   8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                 Outlet_Size Outlet_Location_Type        Outlet_Type  \
# Item_Identifier
# ...

# %%
# get the the data that have this index
data.loc['FDA15']
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# Item_Identifier
# FDA15                    9.3          Low Fat         0.016047     Dairy
# FDA15                    9.3          Low Fat         0.016055     Dairy
# FDA15                    9.3          Low Fat         0.016019     Dairy
# FDA15                    9.3          Low Fat         0.016088     Dairy
# FDA15                    9.3          Low Fat         0.026818     Dairy
# FDA15                    9.3          Low Fat         0.016009     Dairy
# FDA15                    NaN          Low Fat         0.015945     Dairy
# FDA15                    9.3               LF         0.016113     Dairy
#
#                  Item_MRP Outlet_Identifier Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# FDA15            249.8092            OUT049      Medium               Tier 1
# FDA15            250.2092            OUT045         NaN               Tier 2
# ...

# %%
data.loc[['FDE51','FDA15','FDA03','FDU02'],['Item_Type','Item_Visibility','Outlet_Identifier']]
# Out:
#                 Item_Type  Item_Visibility Outlet_Identifier
# Item_Identifier
# FDE51               Dairy         0.161467            OUT010
# FDE51               Dairy         0.096467            OUT046
# FDE51               Dairy         0.096449            OUT035
# FDE51               Dairy         0.168902            OUT019
# FDE51               Dairy         0.097013            OUT017
# FDE51               Dairy         0.096387            OUT013
# FDE51               Dairy         0.096000            OUT027
# FDA15               Dairy         0.016047            OUT049
# FDA15               Dairy         0.016055            OUT045
# FDA15               Dairy         0.016019            OUT035
# FDA15               Dairy         0.016088            OUT018
# FDA15               Dairy         0.026818            OUT010
# FDA15               Dairy         0.016009            OUT013
# FDA15               Dairy         0.015945            OUT027
# ...

# %%
# reset_index of data 
data.reset_index(inplace= True)

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# 0                  Dairy  249.8092            OUT049      Medium
# 1            Soft Drinks   48.2692            OUT018      Medium
# 2                   Meat  141.6180            OUT049      Medium
# 3  Fruits and Vegetables  182.0950            OUT010         NaN
# 4              Household   53.8614            OUT013        High
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# ...

# %%
# filter 
data[data['Item_Type'] == "Dairy"]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 0              FDA15        9.300          Low Fat         0.016047     Dairy
# 11             FDA03       18.500          Regular         0.045464     Dairy
# 19             FDU02       13.350          Low Fat         0.102492     Dairy
# 28             FDE51        5.925          Regular         0.161467     Dairy
# 30             FDV38       19.250          Low Fat         0.170349     Dairy
# ...              ...          ...              ...              ...       ...
# 8424           FDC39        7.405          Low Fat         0.159165     Dairy
# 8447           FDS26       20.350          Low Fat         0.089975     Dairy
# 8448           FDV50       14.300          Low Fat         0.123071     Dairy
# 8457           FDY50        5.800          Low Fat         0.130931     Dairy
# 8512           FDR26       20.700          Low Fat         0.042801     Dairy
#
# ...

# %%
# select spicific range of data
# data[10:30:3]
data[10:30]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 10           FDY07       11.800          Low Fat         0.000000
# 11           FDA03       18.500          Regular         0.045464
# 12           FDX32       15.100          Regular         0.100014
# 13           FDS46       17.600          Regular         0.047257
# 14           FDF32       16.350          Low Fat         0.068024
# 15           FDP49        9.000          Regular         0.069089
# 16           NCB42       11.800          Low Fat         0.008596
# 17           FDP49        9.000          Regular         0.069196
# 18           DRI11          NaN          Low Fat         0.034238
# 19           FDU02       13.350          Low Fat         0.102492
# 20           FDN22       18.850          Regular         0.138190
# 21           FDW12          NaN          Regular         0.035400
# 22           NCB30       14.600          Low Fat         0.025698
# ...

# %%
# get spicific data 
data.iloc[[3,4,9,30,50]]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3            FDX07        19.20          Regular         0.000000
# 4            NCD19         8.93          Low Fat         0.000000
# 9            FDU28        19.20          Regular         0.094450
# 30           FDV38        19.25          Low Fat         0.170349
# 50           NCL17         7.39          Low Fat         0.067780
#
#                 Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# 3   Fruits and Vegetables  182.0950            OUT010         NaN
# 4               Household   53.8614            OUT013        High
# 9            Frozen Foods  187.8214            OUT017         NaN
# 30                  Dairy   55.7956            OUT010         NaN
# 50     Health and Hygiene  143.8812            OUT046       Small
#
#    Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 3                Tier 3      Grocery Store           732.3800
# ...

# %%
# get spicific rows and columns
# row[1,3,4,5], column[1,3,5]
data.iloc[[1,3,4,5], [1,3,5]]
# Out:
#    Item_Weight  Item_Visibility  Item_MRP
# 1        5.920         0.019278   48.2692
# 3       19.200         0.000000  182.0950
# 4        8.930         0.000000   53.8614
# 5       10.395         0.000000   51.4008

# %%
data = data.sort_values(by="Item_Weight")

# %%
data.loc[(data.Item_Type == "Dairy") &(data.Outlet_Size == "Medium")]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 5415           FDW02        4.805          Regular         0.037853     Dairy
# 7899           FDW38        5.325          Regular         0.139245     Dairy
# 2227           FDA38        5.440          Low Fat         0.025584     Dairy
# 1909           FDA38        5.440          Low Fat         0.025520     Dairy
# 7481           FDU50        5.750          Regular         0.075287     Dairy
# ...              ...          ...              ...              ...       ...
# 7826           FDM39          NaN          Low Fat         0.053212     Dairy
# 7837           FDC16          NaN          Regular         0.020470     Dairy
# 7856           FDJ15          NaN          Regular         0.023210     Dairy
# 7987           FDI27          NaN          Regular         0.045764     Dairy
# 8165           FDD39          NaN          Low Fat         0.069815     Dairy
#
# ...

# %%
data.loc[(data.Item_Identifier.isin(["FDW02","FDA38"]),["Item_Weight","Item_Fat_Content","Item_Identifier"])]
# Out:
#       Item_Weight Item_Fat_Content Item_Identifier
# 5415        4.805          Regular           FDW02
# 1500        4.805          Regular           FDW02
# 5514        4.805          Regular           FDW02
# 7667        4.805          Regular           FDW02
# 2227        5.440          Low Fat           FDA38
# 1909        5.440          Low Fat           FDA38
# 6331        5.440          Low Fat           FDA38
# 2035          NaN          Low Fat           FDA38
# 2866          NaN          Regular           FDW02
# 5113          NaN          Regular           FDW02

# %%
data.isna().sum()
# Out:
# Item_Identifier            0
# Item_Weight             1463
# Item_Fat_Content           0
# Item_Visibility            0
# Item_Type                  0
# Item_MRP                   0
# Outlet_Identifier          0
# Outlet_Size             2410
# Outlet_Location_Type       0
# Outlet_Type                0
# Item_Outlet_Sales          0
# dtype: int64

# %%
data.loc[(data.Item_Weight.isna() == True), 'Item_Weight'] = data.Item_Weight.mean()

# %%
data.isna().sum()
# Out:
# Item_Identifier            0
# Item_Weight                0
# Item_Fat_Content           0
# Item_Visibility            0
# Item_Type                  0
# Item_MRP                   0
# Outlet_Identifier          0
# Outlet_Size             2410
# Outlet_Location_Type       0
# Outlet_Type                0
# Item_Outlet_Sales          0
# dtype: int64

# %%
data.loc[(data.Outlet_Size.isna() == True ),"Outlet_Size"] = data.Outlet_Size.mode()

# %%
data.isna().sum()
# Out:
# Item_Identifier            0
# Item_Weight                0
# Item_Fat_Content           0
# Item_Visibility            0
# Item_Type                  0
# Item_MRP                   0
# Outlet_Identifier          0
# Outlet_Size             2410
# Outlet_Location_Type       0
# Outlet_Type                0
# Item_Outlet_Sales          0
# dtype: int64

# %%
data.Item_Fat_Content .value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
# create new col and fil using apply
data["Item_MRP_in_som"] = data.Item_MRP.apply(lambda x: x/27)

# %%
data.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7808           FDP40        4.555          Regular         0.034329
# 4430           FDP40        4.555          Regular         0.034357
# 3489           FDP40        4.555          Regular         0.034351
# 4400           FDP40        4.555          Regular         0.034411
# 3077           DRE12        4.590          Low Fat         0.070767
#
#          Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# 7808  Frozen Foods  110.1544            OUT013        High
# 4430  Frozen Foods  112.6544            OUT046       Small
# 3489  Frozen Foods  112.7544            OUT035       Small
# 4400  Frozen Foods  111.3544            OUT049      Medium
# 3077   Soft Drinks  111.9860            OUT035       Small
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 7808               Tier 3  Supermarket Type1          1230.3984
# 4430               Tier 1  Supermarket Type1          2684.5056
# ...

# %%
data.set_index(data.Item_Identifier, drop = True, inplace= True)

# %%
data[['Item_MRP_in_som',"Item_Type"]]
# Out:
#                  Item_MRP_in_som              Item_Type
# Item_Identifier
# FDP40                   4.079793           Frozen Foods
# FDP40                   4.172385           Frozen Foods
# FDP40                   4.176089           Frozen Foods
# FDP40                   4.124237           Frozen Foods
# DRE12                   4.147630            Soft Drinks
# ...                          ...                    ...
# DRK37                   7.001963            Soft Drinks
# DRG13                   6.101948            Soft Drinks
# NCN14                   6.839289                 Others
# FDU44                   6.013156  Fruits and Vegetables
# NCN18                   4.139052              Household
#
# [8523 rows x 2 columns]

# %%
data = pd.get_dummies(data)

# %%
data
# Out:
#                  Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales  \
# Item_Identifier
# FDP40               4.555000         0.034329  110.1544          1230.3984
# FDP40               4.555000         0.034357  112.6544          2684.5056
# FDP40               4.555000         0.034351  112.7544          1789.6704
# FDP40               4.555000         0.034411  111.3544          1342.2528
# DRE12               4.590000         0.070767  111.9860           792.3020
# ...                      ...              ...       ...                ...
# DRK37              12.857645         0.043792  189.0530          6261.8490
# DRG13              12.857645         0.037006  164.7526          4111.3150
# NCN14              12.857645         0.091473  184.6608          2756.4120
# FDU44              12.857645         0.102296  162.3552           487.3656
# NCN18              12.857645         0.124111  111.7544          4138.6128
#
# ...

# %%
data.shape
# Out:
# (8523, 1605)
