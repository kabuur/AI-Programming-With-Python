# %%
#Importing libraries
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
#Defining independent variable as angles from 10deg to 360deg converted to radians
x = np.array([i*np.pi/180 for i in range(10,360,3)])

# %%
#Setting seed for reproducability
np.random.seed(10)

# %%
#Defining the target/dependent variable as sine of the independent variable
y = np.sin(x) + np.random.normal(0,0.15,len(x))

# %%
#Creating the dataframe using independent and dependent variable
data = pd.DataFrame(np.column_stack([x,y]),columns=['x','y'])

# %%
#Printing first 5 rows of the data
data.head()
# Out:
#           x         y
# 0  0.174533  0.373386
# 1  0.226893  0.332243
# 2  0.279253  0.043827
# 3  0.331613  0.324311
# 4  0.383972  0.467807

# %%
#Plotting the dependent and independent variables
plt.figure(figsize=(12,6))
plt.plot(data['x'],data['y'],'.')

# %%
# polynomial regression with powers of x from 1 to 15
for i in range(2,19):  #power of 1 is already there, hence starting with 2
    colname = f'x_{i}'      #new var will be x_power
    data[colname] = data['x']**i
data.head()
# Out:
#           x         y       x_2       x_3       x_4       x_5       x_6  \
# 0  0.174533  0.373386  0.030462  0.005317  0.000928  0.000162  0.000028
# 1  0.226893  0.332243  0.051480  0.011681  0.002650  0.000601  0.000136
# 2  0.279253  0.043827  0.077982  0.021777  0.006081  0.001698  0.000474
# 3  0.331613  0.324311  0.109967  0.036466  0.012093  0.004010  0.001330
# 4  0.383972  0.467807  0.147435  0.056611  0.021737  0.008346  0.003205
#
#         x_7           x_8           x_9          x_10          x_11  \
# 0  0.000005  8.610313e-07  1.502783e-07  2.622851e-08  4.577739e-09
# 1  0.000031  7.023697e-06  1.593626e-06  3.615823e-07  8.204043e-08
# 2  0.000132  3.698101e-05  1.032705e-05  2.883856e-06  8.053244e-07
# 3  0.000441  1.462338e-04  4.849296e-05  1.608088e-05  5.332620e-06
# 4  0.001231  4.724984e-04  1.814264e-04  6.966273e-05  2.674857e-05
#
#            x_12          x_13          x_14          x_15          x_16  \
# 0  7.989662e-10  1.394459e-10  2.433790e-11  4.247765e-12  7.413749e-13
# 1  1.861438e-08  4.223469e-09  9.582748e-10  2.174257e-10  4.933232e-11
# 2  2.248890e-07  6.280085e-08  1.753731e-08  4.897340e-09  1.367595e-09
# 3  1.768364e-06  5.864117e-07  1.944615e-07  6.448586e-08  2.138432e-08
# 4  1.027071e-05  3.943671e-06  1.514261e-06  5.814344e-07  2.232548e-07
#
#            x_17          x_18
# 0  1.293943e-13  2.258357e-14
# 1  1.119315e-11  2.539645e-12
# 2  3.819047e-10  1.066479e-10
# 3  7.091310e-09  2.351567e-09
# 4  8.572368e-08  3.291553e-08

# %% [markdown]
# ### Creating test and train Set Randomly

# %%
data['randNumCol'] = np.random.randint(1, 6, data.shape[0])
train = data[data['randNumCol']<=3]
test = data[data['randNumCol']>3]
train = train.drop('randNumCol', axis=1)
test = test.drop('randNumCol', axis=1)

# %% [markdown]
# ## Linear Regression

# %%
#Import Linear Regression model from scikit-learn.
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
#Separating the independent and dependent variables
X_train = train.drop('y', axis=1).values
y_train = train['y'].values
X_test = test.drop('y', axis=1).values
y_test = test['y'].values

# %%
#Linear regression with one features
independent_variable_train = X_train[:,0:1]

linreg = LinearRegression()
linreg.fit(independent_variable_train,y_train)
y_train_pred = linreg.predict(independent_variable_train)

print("Training Error =", mean_squared_error(y_train, y_train_pred))

independent_variable_test = X_test[:,0:1]
y_test_pred = linreg.predict(independent_variable_test)

print("Testing Error =", mean_squared_error(y_test, y_test_pred))

plt.plot(X_train[:,0:1],y_train_pred)
plt.plot(X_train[:,0:1],y_train,'.')
plt.show()
# Out:
# Training Error = 0.213144309581739
# Testing Error = 0.18974033118165393

# %%
#Linear regression with three features
independent_variable_train = X_train[:,0:3]

linreg = LinearRegression()
linreg.fit(independent_variable_train,y_train)
y_train_pred = linreg.predict(independent_variable_train)

print("Training Error =", mean_squared_error(y_train, y_train_pred))

independent_variable_test = X_test[:,0:3]
y_test_pred = linreg.predict(independent_variable_test)

print("Testing Error =", mean_squared_error(y_test, y_test_pred))

plt.plot(X_train[:,0:1],y_train_pred)
plt.plot(X_train[:,0:1],y_train,'.')
plt.show()
# Out:
# Training Error = 0.021472481770965682
# Testing Error = 0.030451878881971598

# %%
#Linear regression with nine features
independent_variable_train = X_train[:,0:9]

linreg = LinearRegression()
linreg.fit(independent_variable_train,y_train)
y_train_pred = linreg.predict(independent_variable_train)

print("Training Error =", mean_squared_error(y_train, y_train_pred))

independent_variable_test = X_test[:,0:9]
y_test_pred = linreg.predict(independent_variable_test)

print("Testing Error =", mean_squared_error(y_test, y_test_pred))

plt.plot(X_train[:,0:1],y_train_pred)
plt.plot(X_train[:,0:1],y_train,'.')
plt.show()
# Out:
# Training Error = 0.018764347745716146
# Testing Error = 0.03217644503769279

# %%
#Initialize a dataframe to store the results:
col = ['mse_train','mse_test','intercept'] + [f'coef_Var_{i}' for i in range(1,19)]
ind = [f'Number_of_variables_{i}' for i in range(1,19)]
coef_matrix_simple = pd.DataFrame(index=ind, columns=col)

# %%
def linear_regression(train_x, train_y):
    
    #Fit the model and predict
    linreg = LinearRegression()
    linreg.fit(train_x,train_y)
    train_y_pred = linreg.predict(train_x)
    test_y_pred = linreg.predict(test_x)
    
    
    #add the result in pre-defined format to the dataframe
    mse_train = mean_squared_error(train_y, train_y_pred)
    ret = [mse_train]
    
    mse_test = mean_squared_error(test_y, test_y_pred)
    ret.extend([mse_test])
    
    ret.extend([linreg.intercept_])
    ret.extend(linreg.coef_)
    
    return ret, train_y_pred, test_y_pred

# %%
plt.figure(figsize=(12,8))
# For how many number of features we want to plot
features_to_plot = [1, 3, 6, 9, 12, 15]

for i in range(1,19):
    # select data with i number of features
    train_x = X_train[:,0:i]
    train_y = y_train
    test_x = X_test[:,0:i]
    test_y = y_test
    
    ret, train_y_pred, test_y_pred = linear_regression(train_x, train_y)
    
    coef_matrix_simple.iloc[i-1, 0:i+3] = ret
    
    #Check if a plot is to be made for the entered features
    if i in features_to_plot:
        subplot_position = features_to_plot.index(i)+1
        plt.subplot(2,3,subplot_position)
        plt.plot(train_x[:,0:1],train_y_pred)
        plt.plot(train_x[:,0:1],train_y,'.')
        plt.title(f'Number of Predictors: {i}')

# %%
#Set the display format to be scientific for ease of analysis
pd.options.display.float_format = '{:,.2g}'.format
coef_matrix_simple
# Out:
#                        mse_train mse_test intercept coef_Var_1 coef_Var_2  \
# Number_of_variables_1       0.21     0.19         1      -0.31        NaN
# Number_of_variables_2       0.21     0.19       1.1      -0.39      0.012
# Number_of_variables_3      0.021     0.03      -0.4        2.2      -0.99
# Number_of_variables_4      0.021     0.03     -0.43        2.3         -1
# Number_of_variables_5       0.02    0.023    -0.096        1.2     0.0084
# Number_of_variables_6      0.019    0.028      -0.4        2.5       -1.6
# Number_of_variables_7      0.019    0.028     -0.38        2.4       -1.5
# Number_of_variables_8      0.019    0.032     -0.85        5.1         -7
# Number_of_variables_9      0.019    0.032     -0.94        5.7       -8.5
# Number_of_variables_10     0.018    0.044      -2.4         16        -38
# Number_of_variables_11     0.018    0.034     -0.34      -0.37         15
# Number_of_variables_12     0.018    0.028       1.6        -18         78
# Number_of_variables_13     0.018    0.029      0.84        -10         47
# Number_of_variables_14     0.017    0.056      -5.5         57   -2.4e+02
# Number_of_variables_15     0.017    0.028       1.3        -13         50
# Number_of_variables_16     0.017    0.026       1.4        -12         39
# Number_of_variables_17     0.017    0.036     -0.88        4.1       -1.9
# Number_of_variables_18     0.017    0.033     -0.49        2.3    -0.0049
#
#                        coef_Var_3 coef_Var_4 coef_Var_5 coef_Var_6 coef_Var_7  \
# Number_of_variables_1         NaN        NaN        NaN        NaN        NaN
# Number_of_variables_2         NaN        NaN        NaN        NaN        NaN
# Number_of_variables_3         0.1        NaN        NaN        NaN        NaN
# Number_of_variables_4        0.12     -0.001        NaN        NaN        NaN
# Number_of_variables_5       -0.29      0.069    -0.0043        NaN        NaN
# Number_of_variables_6        0.66       -0.2      0.031    -0.0018        NaN
# Number_of_variables_7        0.53      -0.15      0.021   -0.00067   -5.1e-05
# Number_of_variables_8           6       -3.1       0.92      -0.16      0.015
# Number_of_variables_9         7.7       -4.3        1.4      -0.28      0.033
# Number_of_variables_10         50        -39         19         -6        1.2
# Number_of_variables_11        -38         47        -34         16       -4.7
# Number_of_variables_12   -1.6e+02    1.8e+02   -1.4e+02         67        -22
# Number_of_variables_13        -92         98        -62         23       -3.9
# Number_of_variables_14      6e+02   -9.3e+02    9.5e+02   -6.7e+02    3.3e+02
# Number_of_variables_15        -76         42         26        -59         46
# Number_of_variables_16        -39       -7.3         39        -11        -31
# Number_of_variables_17       -2.4       0.63        2.2       0.21         -2
# Number_of_variables_18       -1.2       -0.7       0.53       0.95     -0.007
#
#                         ... coef_Var_9 coef_Var_10 coef_Var_11 coef_Var_12  \
# Number_of_variables_1   ...        NaN         NaN         NaN         NaN
# Number_of_variables_2   ...        NaN         NaN         NaN         NaN
# Number_of_variables_3   ...        NaN         NaN         NaN         NaN
# Number_of_variables_4   ...        NaN         NaN         NaN         NaN
# Number_of_variables_5   ...        NaN         NaN         NaN         NaN
# Number_of_variables_6   ...        NaN         NaN         NaN         NaN
# Number_of_variables_7   ...        NaN         NaN         NaN         NaN
# Number_of_variables_8   ...        NaN         NaN         NaN         NaN
# Number_of_variables_9   ...      5e-05         NaN         NaN         NaN
# Number_of_variables_10  ...      0.011    -0.00033         NaN         NaN
# Number_of_variables_11  ...      -0.11      0.0073    -0.00021         NaN
# Number_of_variables_12  ...      -0.74       0.071     -0.0039     9.5e-05
# Number_of_variables_13  ...       0.32      -0.077      0.0095    -0.00062
# Number_of_variables_14  ...         30        -5.3        0.67      -0.055
# Number_of_variables_15  ...        6.8        -1.5        0.22      -0.023
# Number_of_variables_16  ...        -24         9.3        -2.4        0.44
# Number_of_variables_17  ...          2        -1.7        0.81       -0.24
# Number_of_variables_18  ...    -0.0091        0.95       -0.86         0.4
#
#                        coef_Var_13 coef_Var_14 coef_Var_15 coef_Var_16  \
# Number_of_variables_1          NaN         NaN         NaN         NaN
# Number_of_variables_2          NaN         NaN         NaN         NaN
# Number_of_variables_3          NaN         NaN         NaN         NaN
# Number_of_variables_4          NaN         NaN         NaN         NaN
# Number_of_variables_5          NaN         NaN         NaN         NaN
# Number_of_variables_6          NaN         NaN         NaN         NaN
# Number_of_variables_7          NaN         NaN         NaN         NaN
# Number_of_variables_8          NaN         NaN         NaN         NaN
# Number_of_variables_9          NaN         NaN         NaN         NaN
# Number_of_variables_10         NaN         NaN         NaN         NaN
# Number_of_variables_11         NaN         NaN         NaN         NaN
# Number_of_variables_12         NaN         NaN         NaN         NaN
# Number_of_variables_13     1.7e-05         NaN         NaN         NaN
# Number_of_variables_14      0.0027    -5.9e-05         NaN         NaN
# Number_of_variables_15      0.0015    -5.8e-05       1e-06         NaN
# Number_of_variables_16      -0.054      0.0044    -0.00021     4.4e-06
# Number_of_variables_17       0.046      -0.006     0.00051    -2.5e-05
# Number_of_variables_18       -0.12       0.023      -0.003     0.00025
#
#                        coef_Var_17 coef_Var_18
# Number_of_variables_1          NaN         NaN
# Number_of_variables_2          NaN         NaN
# Number_of_variables_3          NaN         NaN
# Number_of_variables_4          NaN         NaN
# Number_of_variables_5          NaN         NaN
# Number_of_variables_6          NaN         NaN
# Number_of_variables_7          NaN         NaN
# Number_of_variables_8          NaN         NaN
# Number_of_variables_9          NaN         NaN
# Number_of_variables_10         NaN         NaN
# Number_of_variables_11         NaN         NaN
# Number_of_variables_12         NaN         NaN
# Number_of_variables_13         NaN         NaN
# Number_of_variables_14         NaN         NaN
# Number_of_variables_15         NaN         NaN
# Number_of_variables_16         NaN         NaN
# Number_of_variables_17     5.5e-07         NaN
# Number_of_variables_18    -1.2e-05     2.7e-07
#
# [18 rows x 21 columns]

# %%
sns.lineplot(coef_matrix_simple[['mse_train','mse_test']])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Ridge

# %%
# Importing ridge from sklearn's linear_model module
from sklearn.linear_model import Ridge

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
#Set the different values of alpha to be tested
alpha_ridge = [0, 1e-12, 1e-9, 1e-6, 1e-3, 1e-1, 1, 5, 10, 20]

# %% [markdown]
# 'normalize' parameter for Ridge is removed in version 1.2 of sklearn.

# %%
standard_scaler = StandardScaler()
X_train = standard_scaler.fit_transform(X_train)
X_test = standard_scaler.transform(X_test)

# %%
#Initialize a dataframe to store the results:
col = ['mse_train','mse_test','intercept'] + [f'coef_Var_{i}' for i in range(1,19)]
ind = [f'alpha {i}' for i in alpha_ridge]
coef_matrix_ridge = pd.DataFrame(index=ind, columns=col)

# %%
def ridge_regression(train_x, train_y, alpha):
    
    #Fit the model and predict
    ridge = Ridge(alpha=alpha)
    ridge.fit(train_x,train_y)
    train_y_pred = ridge.predict(train_x)
    test_y_pred = ridge.predict(test_x)
    
    
    #add the result in pre-defined format to the dataframe
    mse_train = mean_squared_error(train_y, train_y_pred)
    ret = [mse_train]
    
    mse_test = mean_squared_error(test_y, test_y_pred)
    ret.extend([mse_test])
    ret.extend([ridge.intercept_])
    ret.extend(ridge.coef_)
    
    return ret, train_y_pred, test_y_pred

# %%
plt.figure(figsize=(12,8))
# For which alpha values we want to plot
alpha_to_plot = [0, 1e-12, 1e-9, 1e-3, 1, 5]

for i in range(10):
    ret, train_y_pred, test_y_pred = ridge_regression(X_train, y_train, alpha=alpha_ridge[i])
    
    coef_matrix_ridge.iloc[i,] = ret
    
    #Check if a plot is to be made for the entered features
    if alpha_ridge[i] in alpha_to_plot:
        subplot_position = alpha_to_plot.index(alpha_ridge[i])+1
        plt.subplot(2,3,subplot_position)
        plt.plot(train_x[:,0:1],train_y_pred)
        plt.plot(train_x[:,0:1],train_y,'.')
        plt.title(f'For alpha value: {alpha_ridge[i]}')

# %%
#Set the display format to be scientific for ease of analysis
pd.options.display.float_format = '{:,.2g}'.format
coef_matrix_ridge
# Out:
#             mse_train mse_test intercept coef_Var_1 coef_Var_2 coef_Var_3  \
# alpha 0         0.015  1.4e+41    -0.003    3.3e+02   -8.4e+03    9.4e+04
# alpha 1e-12     0.018  6.8e+33    -0.003         10        -68        -32
# alpha 1e-09     0.018  1.5e+30    -0.003        9.9        -94    4.7e+02
# alpha 1e-06     0.019  6.7e+29    -0.003          4        -14         17
# alpha 0.001     0.019  1.6e+27    -0.003        2.8       -5.9       -1.1
# alpha 0.1        0.03  2.1e+25    -0.003        1.2         -2       -1.4
# alpha 1         0.062  1.3e+26    -0.003        0.2      -0.77      -0.68
# alpha 5           0.1  6.4e+24    -0.003      -0.19      -0.39      -0.32
# alpha 10         0.11  4.1e+20    -0.003      -0.24      -0.31      -0.24
# alpha 20         0.13  2.1e+24    -0.003      -0.24      -0.25      -0.19
#
#             coef_Var_4 coef_Var_5 coef_Var_6 coef_Var_7  ... coef_Var_9  \
# alpha 0       -4.3e+05   -1.5e+06    3.5e+07   -2.4e+08  ...     -3e+09
# alpha 1e-12    2.4e+03   -1.2e+04    2.4e+04   -1.7e+04  ...    1.5e+04
# alpha 1e-09   -1.3e+03    1.4e+03         31   -1.1e+03  ...    7.2e+02
# alpha 1e-06       -9.5       -5.3      0.034        4.8  ...        7.9
# alpha 0.001        1.7        2.1        1.4        0.4  ...      -0.75
# alpha 0.1        -0.35       0.35       0.66       0.71  ...       0.44
# alpha 1          -0.36     -0.069       0.13       0.25  ...       0.31
# alpha 5          -0.18     -0.065      0.022      0.079  ...       0.13
# alpha 10         -0.15     -0.065    -0.0046      0.036  ...      0.076
# alpha 20         -0.12     -0.066     -0.023     0.0082  ...      0.043
#
#             coef_Var_10 coef_Var_11 coef_Var_12 coef_Var_13 coef_Var_14  \
# alpha 0         6.2e+09    -9.2e+09     9.9e+09    -7.3e+09     3.3e+09
# alpha 1e-12     1.2e+04    -7.4e+03    -1.3e+04    -4.5e+02     9.1e+03
# alpha 1e-09     6.9e+02         -57    -6.1e+02    -4.9e+02          84
# alpha 1e-06        0.75        -8.7         -14         -12        -1.8
# alpha 0.001       -0.79       -0.56       -0.16        0.26        0.58
# alpha 0.1          0.26       0.098      -0.029       -0.12       -0.17
# alpha 1            0.29        0.24        0.18        0.11       0.035
# alpha 5            0.13        0.12       0.098       0.077       0.052
# alpha 10          0.081        0.08       0.074       0.065       0.053
# alpha 20          0.051       0.055       0.056       0.054       0.051
#
#             coef_Var_15 coef_Var_16 coef_Var_17 coef_Var_18
# alpha 0        -5.2e+08    -2.8e+08     1.7e+08      -3e+07
# alpha 1e-12     6.2e+03    -4.9e+03    -4.9e+03       3e+03
# alpha 1e-09     4.9e+02     2.6e+02    -3.3e+02          14
# alpha 1e-06          12          21          13         -24
# alpha 0.001         0.7        0.52      -0.037          -1
# alpha 0.1         -0.19       -0.18       -0.14      -0.088
# alpha 1           -0.04       -0.11       -0.19       -0.26
# alpha 5           0.025     -0.0027      -0.031       -0.06
# alpha 10           0.04       0.026       0.012     -0.0033
# alpha 20          0.047       0.042       0.036        0.03
#
# [10 rows x 21 columns]

# %%
sns.lineplot(coef_matrix_ridge[['mse_train','mse_test']])
plt.xticks(rotation=90)
plt.show()

# %%
alpha_ridge
# Out:
# [0, 1e-12, 1e-09, 1e-06, 0.001, 0.1, 1, 5, 10, 20]

# %%
#Printing number of zeros in each row of the coefficients dataset
coef_matrix_ridge.apply(lambda x: sum(x.values==0),axis=1)
# Out:
# alpha 0        0
# alpha 1e-12    0
# alpha 1e-09    0
# alpha 1e-06    0
# alpha 0.001    0
# alpha 0.1      0
# alpha 1        0
# alpha 5        0
# alpha 10       0
# alpha 20       0
# dtype: int64

# %% [markdown]
# ## Lasso

# %%
#Importing Lasso model from sklearn's linear_model module
from sklearn.linear_model import Lasso

# %%
#Set the different values of alpha to be tested
alpha_lasso = [0, 1e-12, 1e-9, 1e-6, 1e-3, 1e-1, 1, 5, 10, 20]

# %% [markdown]
# 'normalize' parameter for Lasso is removed in version 1.2 of sklearn.
# So, we are applyting Standard scaling to the features before fitting the Lasso model.

# %%
standard_scaler = StandardScaler()
X_train = standard_scaler.fit_transform(X_train)
X_test = standard_scaler.transform(X_test)

# %%
#Initialize a dataframe to store the results:
col = ['mse_train','mse_test','intercept'] + [f'coef_Var_{i}' for i in range(1,19)]
ind = [f'alpha {i}' for i in alpha_lasso]
coef_matrix_lasso = pd.DataFrame(index=ind, columns=col)

# %%
def lasso_regression(train_x, train_y, alpha):
    
    #Fit the model and predict
    lasso = Lasso(alpha=alpha, max_iter=2000)
    lasso.fit(train_x,train_y)
    
    train_y_pred = lasso.predict(train_x)
    test_y_pred = lasso.predict(test_x)
    
    
    #add the result in pre-defined format to the dataframe
    mse_train = mean_squared_error(train_y, train_y_pred)
    ret = [mse_train]
    
    mse_test = mean_squared_error(test_y, test_y_pred)
    ret.extend([mse_test])
    ret.extend([lasso.intercept_])
    ret.extend(lasso.coef_)
    
    return ret, train_y_pred, test_y_pred

# %%
plt.figure(figsize=(12,8))
# For which alpha values we want to plot
alpha_to_plot = [1e-12, 1e-9, 1e-6, 1e-3, 1e-1, 1]

for i in range(10):
    ret, train_y_pred, test_y_pred = lasso_regression(X_train, y_train, alpha=alpha_lasso[i])
    
    coef_matrix_lasso.iloc[i,] = ret
    
    #Check if a plot is to be made for the entered features
    if alpha_lasso[i] in alpha_to_plot:
        subplot_position = alpha_to_plot.index(alpha_lasso[i])+1
        plt.subplot(2,3,subplot_position)
        plt.plot(train_x[:,0:1],train_y_pred)
        plt.plot(train_x[:,0:1],train_y,'.')
        plt.title(f'For alpha value: {alpha_lasso[i]}')
# Out:
# /home/santhosh/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1152: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /home/santhosh/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /home/santhosh/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.144e-01, tolerance: 3.983e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /home/santhosh/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.144e-01, tolerance: 3.983e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/santhosh/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.144e-01, tolerance: 3.983e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/santhosh/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.108e-01, tolerance: 3.983e-03
#   model = cd_fast.enet_coordinate_descent(
# /home/santhosh/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.358e-02, tolerance: 3.983e-03
#   model = cd_fast.enet_coordinate_descent(

# %%
#Set the display format to be scientific for ease of analysis
pd.options.display.float_format = '{:,.2g}'.format
coef_matrix_lasso
# Out:
#             mse_train mse_test intercept coef_Var_1 coef_Var_2 coef_Var_3  \
# alpha 0          0.02  2.4e+24    -0.003        2.7         -6        0.1
# alpha 1e-12      0.02  2.4e+24    -0.003        2.7         -6        0.1
# alpha 1e-09      0.02  2.4e+24    -0.003        2.7         -6        0.1
# alpha 1e-06      0.02  2.4e+24    -0.003        2.7         -6        0.1
# alpha 0.001     0.022  1.8e+26    -0.003        2.1       -4.6         -0
# alpha 0.1         0.2    8e+24    -0.003      -0.52         -0         -0
# alpha 1          0.55     0.56    -0.003         -0         -0         -0
# alpha 5          0.55     0.56    -0.003         -0         -0         -0
# alpha 10         0.55     0.56    -0.003         -0         -0         -0
# alpha 20         0.55     0.56    -0.003         -0         -0         -0
#
#             coef_Var_4 coef_Var_5 coef_Var_6 coef_Var_7  ... coef_Var_9  \
# alpha 0            1.3        1.1       0.66       0.33  ...    -0.0036
# alpha 1e-12        1.3        1.1       0.66       0.33  ...    -0.0036
# alpha 1e-09        1.3        1.1       0.66       0.33  ...    -0.0036
# alpha 1e-06        1.3        1.1       0.66       0.33  ...     -0.004
# alpha 0.001          0       0.97        1.1       0.41  ...          0
# alpha 0.1           -0         -0          0          0  ...          0
# alpha 1             -0         -0         -0         -0  ...         -0
# alpha 5             -0         -0         -0         -0  ...         -0
# alpha 10            -0         -0         -0         -0  ...         -0
# alpha 20            -0         -0         -0         -0  ...         -0
#
#             coef_Var_10 coef_Var_11 coef_Var_12 coef_Var_13 coef_Var_14  \
# alpha 0          -0.063      -0.085      -0.087      -0.078      -0.066
# alpha 1e-12      -0.063      -0.085      -0.087      -0.078      -0.066
# alpha 1e-09      -0.063      -0.085      -0.087      -0.078      -0.066
# alpha 1e-06      -0.062      -0.085      -0.086      -0.078      -0.066
# alpha 0.001           0           0          -0          -0          -0
# alpha 0.1             0           0           0           0           0
# alpha 1              -0          -0          -0          -0          -0
# alpha 5              -0          -0          -0          -0          -0
# alpha 10             -0          -0          -0          -0          -0
# alpha 20             -0          -0          -0          -0          -0
#
#             coef_Var_15 coef_Var_16 coef_Var_17 coef_Var_18
# alpha 0          -0.053      -0.043      -0.036      -0.032
# alpha 1e-12      -0.053      -0.043      -0.036      -0.032
# alpha 1e-09      -0.053      -0.043      -0.036      -0.032
# alpha 1e-06      -0.054      -0.043      -0.036      -0.032
# alpha 0.001          -0          -0      -0.002       -0.34
# alpha 0.1             0           0           0       0.072
# alpha 1              -0          -0          -0          -0
# alpha 5              -0          -0          -0          -0
# alpha 10             -0          -0          -0          -0
# alpha 20             -0          -0          -0          -0
#
# [10 rows x 21 columns]

# %%
sns.lineplot(coef_matrix_lasso[['mse_train','mse_test']])
plt.xticks(rotation=90)
plt.show()

# %%
coef_matrix_lasso.apply(lambda x: sum(x.values==0),axis=1)
# Out:
# alpha 0         0
# alpha 1e-12     0
# alpha 1e-09     0
# alpha 1e-06     0
# alpha 0.001    11
# alpha 0.1      16
# alpha 1        18
# alpha 5        18
# alpha 10       18
# alpha 20       18
# dtype: int64
